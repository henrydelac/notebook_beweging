# %%
print("maateo")
# Out:
# maateo

# %%
r1 = 0.18   # A-C
r2 = 0.24   # B-D
r3 = 0.16   # G-F

# Link 4: C-D-G
l41 = 0.17  # C-D
l42 = 0.25  # D-G
r4 = l41 + l42   # C-G total = 0.42

# Link 5: E-F-H
l51 = 0.13  # E-F
l52 = 0.15  # F-H
r5 = l51 + l52   # E-H total = 0.28

r6 = 0.17   # G-I

# Link 7: H-I-eindpunt
l71 = 0.12  # H-I
l72 = 0.40  # I-eindpunt
r7 = l71 + l72   # H-eindpunt totaal = 0.52

# Afstanden tussen vaste punten
d1 = 0.20   # A-B
d2 = 0.16   # B tot verticaal boven E
d3 = 0.11   # verticale naar E
