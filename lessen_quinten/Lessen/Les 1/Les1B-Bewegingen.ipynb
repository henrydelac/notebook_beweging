# %% [markdown]
# <div style="width: 76ch;">
# <h2>Beweging &mdash; H. Bruyninckx</h2>
# <h3>Kinematisch diagram en mobiliteit</h3>
#
# <p><b>Doelstellingen van deze les</b>:
# <ul>
# <li>kinematisch diagram van een mechanisme.
# <li>mobiliteit van een mechanisme.
# <li>verschil tussen mobiliteit in 2D en in 3D.
# <li>belang van mobiliteits-analyse voor ontwerp van mechanismes.
# </ul>
#
# </div>

# %% [markdown]
# <div style="width: 66ch;">
#
# <h3>Definities en wiskundige voorstellingen</h3>
# <div style="display: grid; grid-template-columns: 1fr 1fr; grid-column-gap: 1%;">
#
# <div>
# <div style=" display: grid; place-items: center; place-content: center;">
#  <div style="height: 20rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/4StrokeEngine_Ortho_3D_Small.gif"
#  >
#  </div>
# <p style="text-align: center;">Fysisch model.
# <p style="font-size: 60%; text-align: center;">(Bron:
# <a href="https://en.wikipedia.org/wiki/Compression_ratio">Wikipedia</a>.)
# </div>
# </div>
#
# <div>
# <div style=" display: grid; place-items: center; place-content: center;">
#  <div style="height: 20rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/zuiger-drijfstang-krukas.svg"
#  >
#  </div>
# <p>Kinematisch model van <em>geledingen</em> (&ldquo;links&rdquo;) en <em>gewrichten</em> (&ldquo;joints&rdquo;).
# </div>
# </div>
#
# </div>
# <style>
#   .opmerking {
#     border-left: 5px solid #2e7d32;
#     background-color: #e8f5e9;
#     color: #1b1b1b;          /* donkere tekst */
#     padding: 14px 18px;
#     margin: 16px 0;
#     font-family: Arial, sans-serif;
#     font-size: 16px;        /* duidelijker */
#     line-height: 1.5;       /* betere leesbaarheid */
#   }
#
#   .opmerking strong {
#     color: #1b5e20;         /* extra nadruk */
#   }
# </style>
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li>Vaak kan je zaken duaal gebruiken, zie dit in
#     <li> Compressor: motor drijft dood punt aan dus dood punt heeft geen impact --> bij motor heb je inertie waardoor dit wel een probleem is
#     <li> V-motoren mijden het dood punt probleem door te werken met uit fase, wel nog vliegwiel dat nuttig is voor trillingsprobleem
#     <li> Trade-off: wat kan het verschil maken tussen het motor concept en het compressieconcept. Je moet dan echt toepssingsgewijs denken en een toepassing geven. Vliegwiel: trilling compenseren of voorbij een dood punt geraken; onbalans krachten eruit krijgen; kostrpijs kWh uit te middelen --> eerst energie in vliegwiel dan later --> afhankelijk van de toepassing is één van deze redenen de verklaring waarom je een vliegwiel kiest! Nadeel van vliegwiel: massa toevoegen; je kan minder snel optrekken (de vraag is of dit belangrijk is in onze toepassing); hoe repititiever de beweging, hoe meer een vliegwiel steekhoudt
#     <li> Wnr geen vliegwiel voor een heel repiitief gegeven? (altijd een toepssing geven, theoretische antwoorden zijn onvoldoende) Een voorbeeld is bv vliegtuigjes -> te zwaar; ook als je direct in een stationair gegeven belandt direct: dan heeft het vliegwiel geen nut
#     <li> Je kan een vliegwiel op een compressor zetten op een compressor zetten om het energiegebruik uit te middelen; anders motor nodig die de volledige compressiekracht regelt en dan is de energie direct weg
#   </ul>
# </div>
# <h3>Gelid (&ldquo;link&rdquo;)</h3>
#
# <ul>
# <li><em>star lichaam</em> met op zijn minst twee <b>aanknopingspunten</b> naar andere gelederen.
# <li>binair (twee aanknopingspunten), ternair (drie aanknopingspunten), quaternair (vier aanknopingspunten),&hellip;
# <li>nummering in kinematisch diagramma:
# <ul>
# <li>gebruik nummers (1,2,&hellip;) om <em>gelederen</em> te identificeren.
# <li>het <em>vaste</em> lichaam (&ldquo;grond&rdquo;) is &ldquo;1&rdquo;.
# </ul>
# <li><a href="https://en.wiktionary.org/wiki/crosshatch#English">arceer</a>
# een gelid met <em>meerdere</em> aanknopingspunten,
# om verwarring te vermijden met <em>binaire</em> gelederen.
# </ul>
#
#
# <div style="height: 10rem;">
#
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/links-binary-ternary-quaternary.svg"
#  >
#  <img style="padding-left: 5ch; border: 0; display: inline-block;" height="100%"
#       src="images/four-bar-with-one-binary-link.svg"
#  >
# </div>
#
#
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li>grond is ook een link: verbind bepaalde zaken
#     <li> Gebruik letters voor connecties --> zelfde conventies gebruiken
#   </ul>
# </div>
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
# <h3>Gewricht &mdash; Kinematisch paar</h3>
# <ul>
# <li>verbinding tussen twee of meer <em>gelederen</em> (aan hun aanknopingspunten), die <em>beweging</em> toelaat tussen de twee verbonden starre lichamen.
# <li>nummering in kinematisch diagramma: gebruik letters: a,b,c,&hellip;
# </ul>
#
# <p><b>Vlakke</b> kinematische paren:
#
# <div style="height: 22rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/table-with-kinematic-pairs.png"
#  >
# </div>
# <style>
#   .opmerking {
#     border-left: 5px solid #2e7d32;
#     background-color: #e8f5e9;
#     color: #1b1b1b;          /* donkere tekst */
#     padding: 14px 18px;
#     margin: 16px 0;
#     font-family: Arial, sans-serif;
#     font-size: 16px;        /* duidelijker */
#     line-height: 1.5;       /* betere leesbaarheid */
#   }
#
#   .opmerking strong {
#     color: #1b5e20;         /* extra nadruk */
#   }
# </style>
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li>Hoe hoger wrijving, hoe lager de kans op slippen (hoge dyn wrijvingscoef), maar meer energie verliezen. Je moet dus kijken of dit van belang is (willen we slip of niet, sommige overbrengingsmechanismen werken met slip)
#   </ul>
# </div>
# <p><b>Ruimtelijke</b> kinematische paren:
#
# <div style="height: 42rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/spatial-kinematic-pairs.png"
#  >
# </div>
#
# <p>Een
# <a href="https://en.wikipedia.org/wiki/Universal_joint">universeel, Cardan, Hooke</a> gewricht laat rotatie toe rond niet perfect uitgelijnde asses.
#
# <p><b>Omkering</b> van een mechanisme.
# Bijvoorbeeld, het <em>vierstangen</em>-mechanisme van hieronder:
# <ul>
# <li>elk van de gelederen kan beschouwd worden als de <em>grond</em>.
# <li>gelederen voeren <em>dezelfde relatieve beweging</em> uit ten opzichte van elkaar.
# </ul>
#
# <div style="height: 20rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/inversion-of-mechanism-four-bar-linkage.png"
#  >
# </div>
#
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li>Eig 4 keer zelfde stangenmechnismen: enkel de grond (statische) is anders bij de vier toepassingen </li>
#     Dit kan een vraag zijn: wat als we de grond ergens anders zetten --> hoe gedraagt het mechanisme zich dan?
#     <li> Soms kan een doodpunt ook een positief ding zijn: bv voor stilstand (je staat stil in een dood punt: je gewicht in je skelet wordt opgenomen zonder dat je je knie moet actueren) of landingsmechanismen </li>
#     Een dood punt kan dus ook een positief gegeven zijn: kracht doorleiden in een bepaalde richting moet zijn moet dan nit gecompenseerd worden door een motor maar wordt gwn opgevangen door de structuur. Dus afhankelijk van de toepassing is het dode punt een voorbeeld ofniet
#   </ul>
# </div>
# <h3>Mobiliteit in het vlak</h3>
#
# <p>(Synomiemen voor &ldquo;mobiliteit&rdquo;: &ldquo;beweegbaarheid&rdquo;, &ldquo;aantal vrijheidsgraden&rdquo;)</p>
#
# <p>De <a href="https://en.wikipedia.org/wiki/Linkage_(mechanical)">mobiliteit</a> van een mechanisme is zijn aantal <em>vrijheidsgraden</em> (degrees of freedom, &ldquo;DOF&rdquo;).
# Met andere woorden: het <em>minimum</em> aantal <em>onafhankelijke</em> coordinaten nodig om de positie en orientatie voor te stellen van <em>elk</em> gelid op <em>elk</em> ogenblik in de tijd.
#
# <p>Mobiliteit in het vlak: formule van
# <a href="https://en.wikipedia.org/wiki/Chebychev%E2%80%93Gr%C3%BCbler%E2%80%93Kutzbach_criterion">Chebychev–Grübler–Kutzbach</a>:
#
# $$M = {\color{red}3}(n − 1) − {\color{blue}2}f_1 − f_2$$
#
#
# $n$: aantal <em>gelederen</em> (merk op dat we er één afrtekken, nl. voor de grond).
# Elke vast gelid verwijdert <span style="color: red;">3</span> DOFs. Elk geleder brengt dus 3 DOF met zich mee
# <br>
# $f_1$: aantal <em>gewrichten</em> met 1 DOF (rotatie of prismatisch).
# Elk verwijdert <span style="color: blue;">2</span> DOFs.
# <br>
# $f_2$: aantal <em>gewrichten</em> met 2 DOFs (nok, volgers, rollers),
# Elk verwijdert <em>1</em> DOFs.
#
# <div style="display: grid; grid-template-columns: 1fr 1fr 1fr; grid-column-gap: 1%;">
#
# <div style=" display: grid; place-items: center; place-content: center;">
#  <div style="height: 10rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/pantograph_animation.gif"
#  >
#  </div>
# <p style="text-align: center;">Pantograaf mechanisme.</p>
#
# $n$: 5; $f_1$: 5; $f_2$: 0 &rarr; $M$: 2.
# <p style="font-size: 60%; text-align: center;">Source: <a href="https://en.wikisource.org/wiki/The_Kinematics_of_Machinery">Wikipedia</a>.
# </div>
#
# <div style=" display: grid; place-items: center; place-content: center;">
#  <div style="height: 12rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/five-bar-linkage-animation.gif"
#  >
#  </div>
# <p style="text-align: center;">&ldquo;Five-bar mechanisme.</p>
#
# $n$: 5; $f_1$: 5; $f_2$: 0 &rarr; $M$: 2.
# <p style="font-size: 60%; text-align: center;">Source: <a href="https://en.wikisource.org/wiki/The_Kinematics_of_Machinery">Wikipedia</a>.
# </div>
#
#
# <div style=" display: grid; place-items: center; place-content: center;">
#  <div style="height: 10rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/six-bar-mechanism.jpg"
#  >
#  </div>
# <p style="text-align: center;">&ldquo;Six-bar&rdquo; mechanisme.</p>
#
# $n$: 6; $f_1$: 7; $f_2$: 0 &rarr; $M$: 1.
# <p style="font-size: 60%; text-align: center;">Source: <a href="https://en.wikisource.org/wiki/The_Kinematics_of_Machinery"><em>The Kinematics of Machinery</em></a>, 18
# 76.
# </div>
#
# </div>
#
# <p>Mobiliteit in het vlak: enkele subtiele voorbeelden</p>
#
# <div style="display: grid; grid-template-columns: 1fr 2fr; grid-column-gap: 8%;">
#
# <div style=" display: grid; place-items: center; place-content: center;">
#  <div style="height: 14rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/linkage-with-three-grounded-links.svg"
#  >
#  </div>
# </div>
#
# <div style="padding-top: 2rem;">
# Algemene formule:
#
# $M = {\color{red}3}(n − 1) − {\color{blue}2}f_1 − f_2$.
#
# Voor dit mechanisme betekent dat:
#
# $n$: 4; $f_1$: 4; $f_2$: 0 &rarr; $M$: 1 ????
#
# &ldquo;Gewricht&rdquo; <span style="color: blue;">d</span> zijn eigenlijk
# <b>twee</b> gewrichten met <b>samenvallende assen</b>.
# Dus: $n$: 4; $f_1$: <b>5</b>; $f_2$: 0 &rarr; $M$: -1. Dit betekent dat je een link moet wegnemen.
# </div>
#
# </div>
#
# <div style="display: grid; grid-template-columns: 1fr 2fr; grid-column-gap: 8%;">
#
# <div style="display: grid; place-items: center; place-content: center;">
#  <div style="height: 14rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/linkage-three-prismatic-joints.png"
#  >
#  </div>
# </div>
#
# <div style="padding-top: 2rem;">
# Algemene formule:
#
# $M = {\color{red}3}(n − 1) − {\color{blue}2}f_1 − f_2$.
#
# Voor dit mechanisme betekent dat:
#
# $n$: 3, $f_1$: 3, $f_2$: 0 &rarr; $M$: 0 ???
#
# Maar het mechanisme is een <b>gelijkzijdige driehoek</b>:
# <ul>
# <li>specifieke <b>geometrische</b> relatie tussen gewrichten
# <br> &emsp; &rarr; &ldquo;singulariteit&rdquo;.
# <li>M = 1, ondanks generieke <b>topologische</b> formule.
# </ul>
# <p class="next" style="padding-top: 1rem;"
# <b>Mechanische toleranties</b> spelen een belangrijke rol in het bepalen of het mechanisme kan bewegen of niet!
# </div>
#
# </div>
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; grid-column-gap: 8%;">
#
# <div style="display: grid; place-items: center; place-content: center;">
#  <div style="height: 17rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/linkage-with-singular-parallellograms.png"
#  >
#  </div>
# </div>
# De extra stangen brengen hier blijkbaar niks op ofs
# <div style="padding-top: 2rem;">
# Algemene formule:
#
# $M = {\color{red}3}(n − 1) − {\color{blue}2}f_1 − f_2$.
#
# $n$: 10; $f_1$: 15; $f_2$: 0 &rarr; $M$: -3 ???
#
# Maar ook dit mechanisme heeft een &ldquo;singulariteit&rdquo;, omdat alle parallellogrammen dezelfde beweging uitvoeren.
#
# &rarr; $n$ = 6, $f_1$ = 7 &rarr; M = 1.
# </div>
#
# </div>
#
# <h3>Mobiliteit in de 3D ruimte</h3>
# <style>
#   .opmerking {
#     border-left: 5px solid #2e7d32;
#     background-color: #e8f5e9;
#     color: #1b1b1b;          /* donkere tekst */
#     padding: 14px 18px;
#     margin: 16px 0;
#     font-family: Arial, sans-serif;
#     font-size: 16px;        /* duidelijker */
#     line-height: 1.5;       /* betere leesbaarheid */
#   }
#
#   .opmerking strong {
#     color: #1b5e20;         /* extra nadruk */
#   }
# </style>
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li>We gaan enkel vlakke mechanismen bestuderen
#   </ul>
# </div>
# Een zelfde redenering als in het 2D vlak leidt tot de volgende 3D formulering van de
# <a href="https://en.wikipedia.org/wiki/Chebychev%E2%80%93Gr%C3%BCbler%E2%80%93Kutzbach_criterion">Chebychev–Grübler–Kutzbach formule</a>:
#
# $$M = \color{red}{6}(n − 1) − \color{blue}{5} f_1 − \color{green}{4} f_2− \color{Maroon}{3} f_3  − \color{DarkGreen}{2} f_4 - \color{DarkBlue}{1} f_5$$
#
# <p>
#
# $n$: aantal <em>gelederen</em>. Elk vast gelid verwijdert <span style="color: red;">6</span> DOFs.
# <br> $f_1$: aantal 1 DOF <em>gewrichten</em>, elk verwijdert <span style="color: blue;">5</span> DOF.
# Bijv.: <em>helisch/schroef</em>-gewricht.
# <br> $f_2$: aantal 2 DOF <em>gewrichten</em>, elk verwijdert <span style="color: green;">4</span> DOF.
# Bijv.: <em>cylindrisch</em> -gewricht.
# <br> $f_3$: aantal 3 DOF <em>gewrichten</em>, elk verwijdert <span style="color: Maroon;">3</span> DOF.
# Bijv.: <em>bal-/sferisch</em> gewricht.
# <br> $f_4$: aantal 4 DOF <em>gewrichten</em>, elk verwijdert <span style="color: DarkGreen;">2</span> DOF.
# Bijv.: ??
# <br> $f_5$: aantal 5 DOF <em>gewrichten</em>, elk verwijdert <span style="color: DarkBlue;">1</span> DOF.
# Bijv.: ??
# </p>
#
# <h3>Mobiliteit in 3D ruimte versus in 2D ruimte</h3>
#
# <div style="display: grid; grid-template-columns: 3fr 2fr; grid-column-gap: 5%;">
# <div>
#
# $n$ = 4; $f_1$ = 4.
#
# <b>2D</b>: $M$ = 3($n$ − 1) − 2$f_1$ = 1
#
# <b>3D</b>: $M$ = 6($n$ − 1) − 5$f_1$ = −2?
#
# <p><b>Verklaring</b>: in het vlak geldt een <b>extra, impliciete <em>geometrische</em></b> bewegingsbeperking, met name dat elk gelid enkel in <em>hetzelfde vlak</em> mag bewegen.
#
# &rarr; alle gewrichtsassen zijn <b>parallel</b>.
#
# &rarr; dit neemt <em>altijd</em> 3 DOFs weg per gelid.
#
# (Tenminste, als de <em>mechanische uitlijning</em> perfect is!)
# </div>
#
# <div style="height: 17rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/four-bar-with-one-binary-link.svg"
#  >
# </div>
#
# </div>
#
# <h3>Mobiliteit in 3D ruimte: ruimtelijk vierstangen-mechanisme</h3>
#
# \begin{aligned}
# M &= {\color{red}6 (n − 1)} - {\color{blue}5 f_1} - {\color{green}4 f_2} - {\color{Maroon}3 f_3} - {\color{DarkGreen}2 f_4} - {\color{DarkBlue}1 f_5}
# \\
#   &= {\color{red}6 \times 3} - {\color{blue}5 \times 2} - {\color{green}4 \times 1}
# - {\color{Maroon}3 \times 1}
# \\
#  &= 1
# \end{aligned}
#
# <div style="display: grid; grid-template-columns: 2fr 1fr; grid-column-gap: 5%;">
#
# <div style="height: 17rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/spatial-four-bar-linkage.png"
#  >
# </div>
#
# <div>
#
# \begin{aligned}
# n &= \color{red}{4} \\
# R &= f_1 = \color{blue}{2} \\
# T &= f_2 = \color{grjen}{1} \\
# S &= f_3 = \color{Maroon}{1} \\
# \end{aligned}
#
# </div>
#
# </div>
#
# <h3>Mobiliteit in 3D ruimte: wielophanging</h3>
# <div style="display: grid; grid-template-columns: 1fr 1fr; grid-column-gap: 5%;">
#
# <div style="height: 20rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/wheel-suspension.png"
#  >
# </div>
#
# <div>
#
# \begin{aligned}
# M &= {\color{red}6 (n − 1)} - {\color{blue}5 f_1} - {\color{green}4 f_2} - {\color{Maroon}3 f_3} - {\color{DarkGreen}2 f_4} - {\color{DarkBlue}1 f_5}
# \\
#   &= {\color{red}6 \times 7} - {\color{blue}5 \times 1} - {\color{green}4 \times 5} - {\color{Maroon}3 \times 5}
# \\
#  &= 2
# \end{aligned}
#
# \begin{aligned}
# n &= {\color{red}8} \\
# R &= f_1 = {\color{blue}1} \\
# T &= f_2 = {\color{green}5} \\
# S &= f_3 = {\color{Maroon}5} \\
# \end{aligned}
#
# De twee vrijheidsgraden zijn: het <em>sturen</em> van het wiel, en de <em>vervorming</em> van de ophangingsveren.
# </div>
#
# </div>
#
# </div>
