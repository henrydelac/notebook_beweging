# %% [markdown]
# <div style="width: 66ch;">
# <h2>Beweging en Trillingen</h2>
# <p>Het vak <a href="https://onderwijsaanbod.kuleuven.be/syllabi/n/H01N0AN.htm#activetab=doelstellingen_idp1557904">Beweging en trillingen</a>
# bestaat uit twee delen:
# <ul>
# <li><b>Deel I: Kinematica en dynamica van machines</b> (&ldquo;beweging&rdquo;, &ldquo;motion&rdquo;)
# <br>
# Herman Bruyninckx.
# <p>Dit deel heeft twee sub-delen:
# <ul>
# <li><a href="https://en.wikipedia.org/wiki/Mechanism_(engineering)">mechanismes</a>:
# starre lichamen verbonden met rotatie- en/of translatie-gewrichten.
# <div style="height: 10rem;">
#  <img src="./images/Hexapod_general_Anim.gif" height="100%" />
#  <img src="./images/Pantograph_Mirror.gif" height="100%" />
# </div>
# <li><b>nokken</b>: starre lichamen verbonden door een &ldquo;rollend contact&rdquo; tussen beide.
# <div style="height: 10rem;">
#  <img src="./images/220px-Nockenwelle.gif" height="100%" />
#  <img src="./images/grabcad-dual-sided-cam.gif" height="100%" />
# </div>
# </ul>
# <p>In beide delen is de <em>dynamica</em> beperkt tot alleen de effecten van <b>inertie</b>
# (&ldquo;<a href="https://en.wikipedia.org/wiki/Newton's_laws_of_motion">wet van Newton</a>&rdquo;).
# <style>
#   .opmerking {
#     border-left: 5px solid #2e7d32;
#     background-color: #e8f5e9;
#     color: #1b1b1b;          /* donkere tekst */
#     padding: 14px 18px;
#     margin: 16px 0;
#     font-family: Arial, sans-serif;
#     font-size: 16px;        /* duidelijker */
#     line-height: 1.5;       /* betere leesbaarheid */
#   }
#
#   .opmerking strong {
#     color: #1b5e20;         /* extra nadruk */
#   }
# </style>
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li>Zoek het conditiegetal van een matrix op</li>
#     <li>Houd rekening met de kost en dergelijke; ook speling is een niet-idealiteit</li>
#     <li> Breng telkens bij alles je toepassingen mee: je moet echt alles hieraan koppelen
#   </ul>
# </div>
#
#
#
# <li><b>Deel II: Mechanische trillingen</b> (&ldquo;trillingen&rdquo;, &ldquo;vibrations&rdquo;)
# <br>
# Elke Deckers.
# <br>
# De <em>dynamica</em> bevat ook de effecten van <b>elasticiteit</b>
# (&ldquo;<a href="https://en.wikipedia.org/wiki/Hooke%27s_law">wet van Hooke</a>&rdquo;)
# zodat trillingen kunnen optreden als uitwisseling van kinetische energie (opgeslagen in de bewegende inertie) en potentiele energie (opgeslagen in de elasticiteit).
# </ul>
#
#
# <h3>Verdere voorbeelden</h3>
# <ul>
# <li><a href="https://duckduckgo.com/?t=ffab&q=youtube+linkage+mechanism&atb=v352-1&ia=web">online zoeken naar <em>mechanismes (&ldquo;linkage&rdquo;)</em>.
# <li>&ldquo;moeder van alle mechanismes&rdquo;: <a href="https://en.wikipedia.org/wiki/Four-bar_linkage ">four-bar linkage</a> (&ldquo;vierstangenmechanisme&rdquo;).
# <li>voorbeelden uit de wereld rondom ons:
# <a href="https://en.wikipedia.org/wiki/Double_wishbone_suspension">wielophanging</a>,
# <a href="https://onlinelibrary.wiley.com/doi/full/10.1002/eng2.12610">ontvouwbare</a>
# <a href="https://www.teslarati.com/spacex-starlink-satellite-prototypes-unique-solar-arrays/">zonnepanelen</a> op een satelliet,
# <a href="https://www.youtube.com/watch?v=z1mGeyYzanc">tuimelschijf</a> (&ldquo;swashplate&rdquo;) van een helikopter,
# <a href="https://en.wikipedia.org/wiki/Crankshaft">nokkensas</a>,&hellip;
# </ul>
#
# <h3>Huiswerk voor de oefenzitting</h3>
#
# <ul>
# <li><b>jij</b> (in een groep van twee studenten) zoekt een mechanisme, of vindt er &eacute;&eacute;n uit dat je zal gebruiken in je <b>examen-project</b>.
# <li>bereid op zijn minst <b>drie mechanismes</b> voor, met tenminste <b>acht links</b> en met <b>mobiliteit &ldquo;1&rdquo;</b>.
# <li>elke groep moet een <b>origineel, uniek</b> mechanisme vinden.
# <li><b>deadline</b>: 7 maart.
# </ul>
#
# </div>

# %% [markdown]
# <div>
# <div style="width: 66ch;">
# <h2>Doelstellingen van het vak</h2>
# <ul>
# <li> gebruik kennis uit <em>Toegepaste Mechanica 1-2-3</em> op <b>vlakke mechanismen</b>.
# Nieuwe kennis bestaat vooral uit
# <b>beperkingen op de vrije beweging</b> van de mechanismen.
# <li>kinematische en dynamische berekeningen uitvoeren <b>op computer</b>.
# <li><b>vaardigheid</b> ontwikkelen om &ldquo;wat als?&rdquo; discussies te voeren, op het <b>mondelinge examen</b>.
# <li>systematisch en nauwkeurig gebruik van <b>fysische eenheden</b>: <em>elk getal</em> heeft eenheden&hellip;
# <li><b>kritische interpretatie</b> van <b>numerieke resultaten</b>,
# gebaseerd op <b>fysisch inzicht</b>:
# je moet de grootteorde van de berekende resultaten al kunnen inschatten
# vooraleer je de berekeningen uitvoert.
# <li><b>kritische en creatieve houding</b> ten opzichte van het nut en
# het gebruik van je kennis in de <b>echte wereld</b>:
# <ul>
# <li>is je systeem/aanpak/oplossing &ldquo;optimaal&rdquo;, in &eacute;&eacute;n of andere zin?
# <li>voor welk <b>toepassingsdomein</b> is die optimaliteit echt nuttig?
# <li>misschien is &ldquo;<b>goed genoeg</b>&rdquo; ook wel goed genoeg!
# Maar hoe weet je wat &ldquo;goed genoeg&rdquo; is&hellip;
# </div>

# %% [markdown]
# <div>
# <div style="width: 100ch;">
# <h2>Opmerkingen les</h2>
# <ul>
# <li> Altijd een vraag over kWh en wrijving
# <style>
#   .opmerking {
#     border-left: 5px solid #2e7d32;
#     background-color: #e8f5e9;
#     color: #1b1b1b;          /* donkere tekst */
#     padding: 14px 18px;
#     margin: 16px 0;
#     font-family: Arial, sans-serif;
#     font-size: 16px;        /* duidelijker */
#     line-height: 1.5;       /* betere leesbaarheid */
#   }
#
#   .opmerking strong {
#     color: #1b5e20;         /* extra nadruk */
#   }
# </style>
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li>Je moet altijd rekening houden met iets van wrijving: vaak vraagt hij aan welke wrijving er belangrijk is en dergelijke --> vermogenberekeningen
#     <li> Breng telkens bij alles je toepassingen mee: je moet echt alles hieraan koppelen
#   </ul>
# </div>
# <li> Plenair, wordt aan twee zijden gevraagd
# <li> Enkel wet van Newton en Hooke ens gebruiken, vrij eenvoudig inhoudelijk maar kost veel werk
# <li> Op beiden delen van het vak slagen; enkel onvoldoende opnieuw doen
# <li> Ieder krijgt aparte machine met een bijhorende nok; je ma g de input wel veranderen: dit toont dat je nadenkt over wat je kan doen en dergelijke
# <li> Je mag ook alles zelf kiezen en dergelijke op het examen; gwn zelf de zaken bepalen en dan zeggen waarom je dit doet (voor een bepaalde toepassing en dergelijke)
# <li> Je moet ook ergens een aanpassing aan je code of mechanisme doen en dan voorspellen wat er gaat gebeuren: stel je maakt bepaalde stangen of vrijheidsgraden langer of korter: wat gaat er dan veranderen? Je moet deze veranderingen ook daar terplekke kunnen doorrekenen om je voorspelling te bewijzen (deze numerieke anlasyse is ook bel, maar je moet zelf een idee hebben van in welke trend dit gaat)
# <li> Je mag code samen ontwikkel, maar moet gwn alles bewijzen (ind in het examen)
# <li> Vaak stelt hij ook de vraag van wat als ik met één motor vijf circuits parallel zet en terug aandrijf --> je wilt deze uit fase gaan brengen ens om dan het energieverbruik van de motor beter verdelen zodat je niet telkens op hetzelfde moment een piek krijgt
# <li> Alles heeft eenheden, dit is belangrijk voor hem
# <li> Denk ook aan de prijs voor zaken
#
# </div>

# %% [markdown]
# <div style="width: 66ch;">
# <h2>Evaluatie van het gedeelte &ldquo;Beweging&rdquo;</h2>
# <p>Gebeurt aan de hand van <b>twee projecten</b>:
# <ul>
# <li>&eacute;&eacute;n over <b>stangenmechanismen</b>, en &eacute;&eacute;n over <b>nokken</b>.
# <li>beide projecten staan op 50% van de punten. Voor beide kies je zelf de toepassing.
# <li>elk project gebeurt door een <b>team van twee studenten</b>,
# uit <b>dezelfde oefeningen-reeks</b>, en met hetzelfde team voor beide projecten.
# <li>de projecten starten in de oefensessies, en je zet ze verder op eigen kracht.
# <li>vragen kan je stellen via Toledo (docent en assistenten volgen het forum).
# <li>elk project is een <em>Jupyter notebook</em>, zoals dit document.
# Je levert die in aan het einde van het semester.
# <li>zo'n <em>notebook</em> bevat alle berekeningen, dus kunnen we makkelijk &ldquo;wat als?&rdquo; vragen stellen op het <b>mondelinge examen</b>.
# <li>er is een apart <b>mondeling examen</b> van 20 minuten, voor elk van beide projecten.
# </ul>
#
#
#
# <p><b>Tijdsbudget/student</b> (totaal = 90 uren):
# <ul>
# <li>lessen: 14 uur.
# <li>oefensessies: 10 uur.
# <li>projecten: &approx; 30 + 30 = 60 uur.
# </ul>
# <p><b>Score-criteria</b>:
# <ul>
# <li>inzichten. Worden vooral getest op basis van &ldquo;wat als?&rdquo; vragen.
# <li>correcte berekeningen.
# <li>creativiteit en kritische reflectie. Bijvoorbeeld: welke industrie is gebaat met jullie stangenmechanisme, en jullie nokken?
# </ul>
#
#
# <h3>Evaluatie van het hele vak (Delen I + II)</h3>
# <p>Je krijgt <b>&eacute;&eacute;n score</b> voor het hele vak.
# Als je score lager is dan <b>10/20</b>, dan contacteer je de docenten om na te gaan welk deel van het vak moet herdaan worden in het herexamen.
# Als je zo'n gedeeltelijke vrijstelling hebt verkregen van vorig academiejaar, dan check je dat best nog eens even met de betrokken docent.
# <style>
#   .opmerking {
#     border-left: 5px solid #2e7d32;
#     background-color: #e8f5e9;
#     color: #1b1b1b;          /* donkere tekst */
#     padding: 14px 18px;
#     margin: 16px 0;
#     font-family: Arial, sans-serif;
#     font-size: 16px;        /* duidelijker */
#     line-height: 1.5;       /* betere leesbaarheid */
#   }
#
#   .opmerking strong {
#     color: #1b5e20;         /* extra nadruk */
#   }
# </style>
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li>Vragenuurtjes zijn soort proefexamens
#     <li> Je moet de notebook op voorhand ook doorsturen, niet dat ze dit doornemen maar gwn als backup voor hun indien uw pc crasht
#   </ul>
# </div>
# </div>

# %% [markdown]
# <div style="width: 66ch;">
# <h2>Inhoud van het deel &ldquo;Beweging&rdquo;</h2>
# <h3>Technische reikwijdte en kennis</h3>
# <ul>
# <li><b>kinematica</b>: geometrische beweging over de tijd, van een mechanisch gekoppeld systeem van
# <a href="https://en.wikipedia.org/wiki/Rigid_body_dynamics"><b>starre lichamen</b></a>.
# Dat wil zeggen, je kan de <em>positie</em>, <em>snelheid</em>, en <em>versnelling</em> berekenen van gelijk welk punt op gelijk welk star lichaam in het systeem.
# <li><b>dynamica</b>: het effect dat <b>krachten</b> hebben op de beweging van het systeem.
# Als het starre lichaam in rust is en blijft, dan noemen we dat de
# (<a href="https://en.wikipedia.org/wiki/Statics"><b>statica</b></a>),
# of &ldquo;krachtenevenwicht&rdquo;.
# <br>Als de krachten de beweging van de starre lichamen wijzigt, dan noemen we dat de
# <a href="https://en.wikipedia.org/wiki/Rigid_body_dynamics"><b>kinetica</b></a>.
# De onderliggende fysische wetmatigheden zijn de
# <a href="https://en.wikipedia.org/wiki/Newton%27s_laws_of_motion">wetten van Newton</a>,
# via de
# <a href="https://en.wikipedia.org/wiki/List_of_moments_of_inertia"><b>inertie</b></a>
# van de starre lichamen.
#
# <li><b>(stangen)-mechanismes</b> (zoals het
# <a href="https://en.wikipedia.org/wiki/Slider-crank_linkage">kruk-drijfstang</a>-mechanisme in een
# <a href="https://en.wikipedia.org/wiki/Internal_combustion_engine">verbrandingsmotor</a>),
# en <b>nok-aandrijvingen</b>:
# <ul>
# <li>de <b>mechanische koppeling</b> zorgt voor een <b>deterministische</b> relatieve beweging.
# <li>in deze cursus beschouwen we enkel systemen met
# <a href="https://en.wikipedia.org/wiki/Degrees_of_freedom_(mechanics)"><b>&eacute;&eacute;n vrijheidsgraad</b></a>.
# Met andere woorden, &eacute;&eacute;n enkele
# <a href="https://en.wikipedia.org/wiki/Actuator">actuator</a> (of &ldquo;motor&rdquo;) is voldoende voor de aandrijving van het systeem.
# </ul>
#
# <li><b> machines</b> (zoals de hogervermelde verbrandingsmotor), zijn een collectie van mechanismes, aangedreven door een collectie van actuatoren, om een nuttige beweging te genereren voor de maatschappij.
# </ul>
#
# We bestuderen de <b>traject-berekeningen</b> van mechanismes en nokken, en
# de <b>verbanden</b> met de <b>trillingen</b> die mogelijkerwijze zouden kunnen ontstaan als een gevolg van die bewegingen.
#
# </div>

# %% [markdown]
# <div style="width: 66ch;">
#
# <h3>Aannames in dit vak</h3>
#
# <ul>
# <li>alle gelederen en nokken zijn <b>starre lichamen</b>, zoals in deze
# <a href="https://www.youtube.com/watch?v=9CJ032fnLOM">graafmachine</a>.
# We beschouwen dus geen <b>flexibele mechanismes</b>, zoals
# <a href="https://www.youtube.com/watch?v=eXULfD94gho">dit</a>.
# <li>alle wiskundige beschrijvingen gebruiken enkel modellen met
# <a href="&ldquohttps://en.wikipedia.org/wiki/Lumped-element_model">geconcentreerde parameters&rdquo;</a>:
# massa's, veren en dempers.
# </ul>
# </ul>

# %% [markdown]
# <div style="width: 66ch;">
#
# <h2>Voorbeeld: weefmachines</h2>
# <p>Vlaanderen heeft <b>twee wereldleiders</b> in deze industrie:
# <ul>
# <li><a href="https://www.picanol.be/machines-features/machines">Picanol</a>
# (<a href="https://www.youtube.com/watch?v=Rjxx_4MeOAg">video</a>).
#
# <li><a href="https://vandewiele.com/textile-solutions/weaving/carpet-weaving-machines">Vandewiele</a>
# (<a href="https://www.youtube.com/watch?v=G5ZKLj5cHJg">video</a>).
# </ul>
# <style>
#   .opmerking {
#     border-left: 5px solid #2e7d32;
#     background-color: #e8f5e9;
#     color: #1b1b1b;          /* donkere tekst */
#     padding: 14px 18px;
#     margin: 16px 0;
#     font-family: Arial, sans-serif;
#     font-size: 16px;        /* duidelijker */
#     line-height: 1.5;       /* betere leesbaarheid */
#   }
#
#   .opmerking strong {
#     color: #1b5e20;         /* extra nadruk */
#   }
# </style>
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li>Luchtstroom om draad te begeleiden
#   </ul>
# </div>
# <p>Terminologie:
# <ul>
# <li><a href="https://nl.wikipedia.org/wiki/Weven">weven</a>.
# <li><a href="https://nl.wikipedia.org/wiki/Weefgetouw">weefgetouw</a>.
# <li><a href="https://nl.wikipedia.org/wiki/Schering_(textiel)">schering</a>
# en <a href="https://nl.wikipedia.org/wiki/Inslag_(textiel)">inslag</a>.
# <li><a href="https://en.wikipedia.org/wiki/Reed_(weaving)">riet</a>
# en
# <a href="https://textilelearner.net/beat-up-mechanism-in-weaving-motion/">weeflade</a>.
# </ul>
#
# </div>
