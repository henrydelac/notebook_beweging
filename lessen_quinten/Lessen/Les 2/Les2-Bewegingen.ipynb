# %% [markdown]
# <div style="width: 76ch;">
# <h2>Beweging: Les 2 &mdash; H. Bruyninckx</h2>
# <h3>Kinematische analyse van vlakke mechanismes</h3>
#
# <p><b>Doelstellingen van deze les</b>.
# We bestuderen de kinematische analyse van vaak voorkomende mechanismes:
# <ul>
# <li>vlak vierstangenmechanisme (&ldquo;four bar&rdquo;).
# <li>vlak kruk-drijfstang-mechanisme (&ldquo;slider-crank&rdquo;).
# <li>snelle-terugkeer-mechanisme (&ldquo;quick return&rdquo;).
# <li>mechanisme voor onderbroken beweging (&ldquo;intermittent motion&rdquo;).
# </ul>
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
# <h3>Waarom gebruiken we mechanismes?</h3>
#
# <div style="display: grid; grid-template-columns: 2fr 3fr; grid-column-gap: 1%;">
#
# <div>
# <ul>
# <li>&eacute;&eacute;n centrale motor kan verschillende deelsystemen aandrijven.
# <li>op een gemiddelde snelheid, met uitgemiddelde inerti&euml;le belasting.
# </ul>
#
# Dit was <b>essentieel</b> v&oacute;&oacute;r de tijd van computergestuurde (&ldquo;mechatronische&rdquo;) aandrijvingen,
# maar voor heel wat toepassingen blijven mechanismes competitief, omwille van prijs/performantie. Bijvoorbeeld in weefgetouwen.
# </div>
#
# <div style=" display: grid; place-items: center; place-content: center;">
#  <div style="height: 20rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/Belts-drives-in-one-of-Boschs-workshops-1920-352131505082.jpg"
#  >
#  </div>
# <p style="padding-top: 0.5rem; font-size: 60%;"><a href="https://commons.wikimedia.org/wiki/File:Belts-drives-in-one-of-Boschs-workshops-1920-352131505082.jpg">(Wikipedia)
# </a></p>
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="width: 96ch;">
# <h2>Vierstangenmechanisme<br> (&ldquo;stangenvierzijde&rdquo;, &ldquo;<a href="https://en.wikipedia.org/wiki/Four-bar_linkage">four-bar linkage</a>&rdquo;)</h2>
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; grid-column-gap: 3ch;">
#
# <div style="display: grid; place-items: center; place-content: center;">
#  <div style="height: 20rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/planar-four-bar-linkage.png"
#  >
#  </div>
# </div>
# <div>
#
# <b>Terminologie</b>:
#
# <div style="display: grid; grid-template-columns: 1fr 15fr; grid-column-gap: 1%;">
# <div>1:</div>
# <div>grond, frame.</div>
# </div>
#
# <div style="display: grid; grid-template-columns: 1fr 15fr; grid-column-gap: 1%;">
# <div>2:</div>
# <div>aandrijvend gelid (&ldquo;input link&rdquo;, &ldquo;driver&rdquo;).
# <br>
# &emsp;(Aanname: de <b>actuator</b> hangt hieraan vast.)
# </div>
# </div>
#
# <div style="display: grid; grid-template-columns: 1fr 15fr; grid-column-gap: 1%;">
# <div>3:</div>
# <div>koppelstang (&ldquo;coupler&rdquo;). </div>
# </div>
#
# <div style="display: grid; grid-template-columns: 1fr 15fr; grid-column-gap: 1%;">
# <div>4:</div>
# <div>aangedreven gelid (&ldquo;output link&rdquo;).
# <br>
# &emsp;(Aanname: de <b>taak</b>  hangt hieraan vast.)
# </div>
# </div>
#
# <div style="display: grid; grid-template-columns: 1fr 15fr; grid-column-gap: 1%;">
# <div>
#
# $\theta_2$:
# </div>
# <div>invoer-hoek (&ldquo;input angle&rdquo;).  </div>
# </div>
#
# <div style="display: grid; grid-template-columns: 1fr 15fr; grid-column-gap: 1%;">
# <div>
#
# $\theta_4$:
# </div>
# <div>uitvoer-hoek (&ldquo;output angle&rdquo;).</div>
# </div>
#
# <div style="display: grid; grid-template-columns: 1fr 15fr; grid-column-gap: 1%;">
# <div>
#
# $\gamma$:
# </div>
# <div> overbrengings-hoek (&ldquo;transmission angle&ldquo;). </div>
# </div>
#
# </div>
# </div>
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
# <p>Een aantal varianten op het canonieke vierstangen-mechanisme vind je <a href="https://commons.wikimedia.org/wiki/Category:Animations_of_mechanical_linkages">hier</a>. Ze hebben dezelfde <em>topologie</em> maar de links hebben verschillende <em>geometrische afmetingen</em>.
#
#  <div style="height: 20rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/Grashof_Type_I_Four-Bar_Kinematic_Inversions.gif"
#  >
#  </div>
#
#
# <p><b>Terminologie</b>:
# <style>
#   .opmerking {
#     border-left: 5px solid #2e7d32;
#     background-color: #e8f5e9;
#     color: #1b1b1b;          /* donkere tekst */
#     padding: 14px 18px;
#     margin: 16px 0;
#     font-family: Arial, sans-serif;
#     font-size: 16px;        /* duidelijker */
#     line-height: 1.5;       /* betere leesbaarheid */
#   }
#
#   .opmerking strong {
#     color: #1b5e20;         /* extra nadruk */
#   }
# </style>
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li>Puur op basis van de geometrie krijg je andere type machines en dergelijke
#   </ul>
# </div>
# <div style="display: grid; grid-template-columns: 1fr 1fr; grid-column-gap: 1%;">
# <div>
# <ul>
# <li><b>zwengel</b> (<b>crank</b>): het gelid dat een volledige cirkel kan ronddraaien.
# </ul>
# </div>
# <div>
# <ul>
# <li><b>tuimelaar</b> (<b>rocker</b>): het gelid dat een beperkt rotatie-bereik heeft.
# </ul>
# </div>
# </div>
# <table style="width: auto; margin-left:auto; margin-right:auto;">
# <tr>
#  <th>type
#  <th>aandrijvend gelid
#  <th>aangedreven gelid
#  <th>dode punten
# </tr>
# <tr>
#  <td>double crank (&ldquo;drag&rdquo; + &ldquo;link&rdquo;)
#  <td>crank of kruk
#  <td>crank
#  <td>neen
# </tr>
# <tr>
# <td>crank-rocker
# <td>crank
# <td>rocker
# <td>neen
# </tr>
# <tr>
# <td>crank-rocker
# <td>rocker (wat heen en weer gaat)
# <td>crank
# <td>neen, met <a href="https://en.wikipedia.org/wiki/Flywheel">vliegwiel</a>
# </tr>
# <tr>
# <td>double rocker
# <td>rocker
# <td>rocker
# <td>ja
# </tr>
# </table>
#
# <p style="text-align: center;">Meer informatie:
# <a href="https://en.wikipedia.org/wiki/Four-bar_linkage#Grashof_condition">Grashof voorwaarden</a>.
# </p>
#
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li>Dit onderste in se niet van buiten kennen maar geeft inzicht in wat veranderingen teweeg brengen en dergelijke
#     <li> Dit bovenste gaat hij sws wel eens vragen, is toepassingsafhankelijk
#     <li> Weet gwn dat er verschillende voorwaarden zijn, maar termen zelf zijn niet belangrijk
#   </ul>
# </div>
#
# <div style=" display: grid; place-items: center; place-content: center;">
#  <div style="height: 14rem;">
# <a href="https://en.wikipedia.org/wiki/Four-bar_linkage">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/four-bar-linkage-crank-rocker.svg"
#  >
# </a>
#  </div>
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
# <h3>Dood punt &mdash; Singulariteit</h3>
# Als het aandrijvend gelid 2 volledig roteert, dan is er geen gevaar dat het mechanisme blokkeert.
# Maar als het aandrijvend gelid 2 <em>oscilleert</em> (zoals de <em>tuimelaar/rocker</em> in de figuur hieronder), dan zou het kunnen dat het mechanisme blokkeert op zijn uiterste standen,
# omdat de <em>aangrijpingslijn</em> van de aandrijvende kracht ligt in de <em>richting van gelid 4</em>.
# Dus, in dat geval moet er voldoende inertie (&ldquo;vliegwiel&rdquo;, &ldquo;flywheel&rdquo;) voorzien worden,
# zodat het mechanisme <em>doorheen het dode punt</em> kan verderbewegen.
#
#
# <div style="padding-top: 1rem; display: grid; place-items: center; place-content: center;">
#  <div style="height: 10rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/four-bar-dead-point.svg"
#  >
#  </div>
# </div>
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
# <h3>Overbrengings-/transmissie-hoek</h3>
#
# <div style=" display: grid; place-items: center; place-content: center;">
#  <div style="height: 15rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/planar-four-bar-linkage.png"
#  >
#  </div>
# </div>
# <style>
#   .opmerking {
#     border-left: 5px solid #2e7d32;
#     background-color: #e8f5e9;
#     color: #1b1b1b;          /* donkere tekst */
#     padding: 14px 18px;
#     margin: 16px 0;
#     font-family: Arial, sans-serif;
#     font-size: 16px;        /* duidelijker */
#     line-height: 1.5;       /* betere leesbaarheid */
#   }
#
#   .opmerking strong {
#     color: #1b5e20;         /* extra nadruk */
#   }
# </style>
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li> Hoek gamma is belangrijk, hoe dichter bij 90° hoe efficienter de overbrenging
#     <li> Andere hoeken bepalen met cos regel en dergelijke
#   </ul>
# </div>
# De hoek $\gamma$ is de <em>overbrengingshoek</em>
# tussen de <b>koppelstang</b> 3 en de <b>uitvoer</b> 4.
# Uit de <a href="https://en.wikipedia.org/wiki/Law_of_cosines">cosinus-regel</a>, $c^2=a^2 + b^2 -2ab\cos(\gamma)$, volgt dat
# $$
# \gamma = \cos^{−1} \left[
# \frac{
# r_1^2 + r_2^2 − r_3^2 − r_4^2 − 2r_1 r_2 \cos{(\theta_2)}
# }
# {−2r_3 r_4}
# \right].
# $$
#
# De overbrengingshoek ligt best zo dicht mogelijk bij een rechte hoek
# (ver weg van de dode punten rond 0&deg; en 180&deg;), omdat dan het koppel van de aandrijving maximaal wordt doorgegeven aan de uitvoer. De figuur hieronder schetst twee transmissie-paden ("1" en "2") van hetzelfde invoerkoppel $\tau_i$:
# <ul>
# <li>
#
# de links zijn verbonden door rotatie-gewrichten, en die geven maar een deel van de kracht door naar het volgende gelid. Meer concreet, de krachten 1' en 2'.
#
# <li>
#
# aan het eind leveren die doorgegeven krachten opnieuw een uitvoer-koppel $\tau_o$.
#
# <li>de configuratie waar de transmissie-hoek het dichtst bij 90 graden ligt, met name, de <b>zwarte</b> configuratie, is meer efficiënt in het doorgeven van het invoer-koppel naar de uitvoer dan de <span style="color:blue;"><b>blauwe</b></span> configuratie.
# </ul>
#
# <div style="padding-top: 1rem; display: grid; place-items: center; place-content: center;">
#  <div style="height: 12rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/four-bar-transmission-angle.svg"
#  >
#  </div>
# </div>
#
#
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li>Dit zijn staafmechanismen, de overbrenging van de krachten door één staaf is dus altijd nominaal, bij gamma = 90°, is dit optimaal
#     <li> Je moet goed kunnen weten dat daar waar onze werking het kritsch is: zijnde meeste koppel of energie van onze motor laten gebruiken; daar moet de overbrengingshoek het beste zijn (afhankelijk van de toepassing is dit dan 90°); dit is sws een examenvraag --> daar waar kritisch is, moet transmissiehoek het beste zijn </li>
#     Bij landingsmechanisme was dit dus 180°: dit wouden we omdat er dan geen kracht wordt doorgeleid
#   </ul>
# </div>
#
# Hieronder staat een vierstangen-mechanisme waarvan de gelederen zo lang zijn dat er meer dan &eacute;&eacute;n overbrengingshoek $\gamma$ mogelijk is.
#
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li> Iets van  ofwel naar boven ofwel naar beneden, dit had veel te maken met de configuratie waarin je u bevindt ofs
#     <li> Ook van of je wilt of je nr boven of beneden gaat
#   </ul>
# </div>
#
# <div style=" display: grid; place-items: center; place-content: center;">
#  <div style="height: 15rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/fourbar-linkage-inverted.png"
#  >
#  </div>
# </div>
#
# De <em>tuimerlaars</em> (&ldquo;rockers&rdquo;) kunnen niet van de ene configuratie naar de andere overgaan, zonder mechanisch losgekoppeld te moeten worden.
#
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
# <h3>Positie-analyse gebaseerd op geometrisch inzicht</h3>
#
# <style>
#   .opmerking {
#     border-left: 5px solid #2e7d32;
#     background-color: #e8f5e9;
#     color: #1b1b1b;          /* donkere tekst */
#     padding: 14px 18px;
#     margin: 16px 0;
#     font-family: Arial, sans-serif;
#     font-size: 16px;        /* duidelijker */
#     line-height: 1.5;       /* betere leesbaarheid */
#   }
#
#   .opmerking strong {
#     color: #1b5e20;         /* extra nadruk */
#   }
# </style>
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li>We gaan van positie tot versnelling. De vraag is of je ook grotere ordes dan versnellingen hebt: dit is het geval bij discontinuïteiten, door abrupte bewegingen kan je trillingen krijgen die dus door elastische effecten grotere ordes geven. Dit is dus niet ideale mechanica die boven de acceleratie gaat, maar hier zijn geen mechanica wetten voor!
#   </ul>
# </div>
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; grid-column-gap: 1%;">
#
# <div style=" display: grid; place-items: center; place-content: center;">
#  <div style="height: 15rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/planar-four-bar-linkage.png"
#  >
#  </div>
# </div>
#
# <div style=" display: grid; place-items: center; place-content: center;">
#  <div style="height: 15rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/fourbar-linkage-inverted.png"
#  >
#  </div>
# </div>
# </div>
#
# De <em>voorwaartse</em> positie-analyse start met een gegeven
# $\theta_2$ (want daar zit doorgaans de aangedreven motor, waar een
# <a href="https://en.wikipedia.org/wiki/Rotary_encoder">hoek-encoder</a> die hoek $\theta_2$ meet),
# en zoekt de hoeken $\theta_3,\theta_4$ (waar de &ldquo;taak&rdquo; van het mechanisme zit).
#
# <em>Ad hoc</em> methode:
#
# $\theta_4 = \pi - (\alpha + \beta)$, met
# $\alpha = \cos^{-1}\left[ \frac{r_3^2 - z^2 -r_4^2}{-2 r_4 z}\right]$,
# en $\beta = \cos^{-1}\left[ \frac{r_2^2 - z^2 -r_1^2}{-2 r_1 z}\right]$,
#
# Dat geeft <em>twee oplossingen</em>, want:
# $z^2 = r_1^2 +r_2^2 -2 r_1 r_2 \cos(\theta_2)$.
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
# <h3>Positie-analyse gebaseerd op sluitingsvergelijkingen</h3>
#
# <style>
#   .opmerking {
#     border-left: 5px solid #2e7d32;
#     background-color: #e8f5e9;
#     color: #1b1b1b;          /* donkere tekst */
#     padding: 14px 18px;
#     margin: 16px 0;
#     font-family: Arial, sans-serif;
#     font-size: 16px;        /* duidelijker */
#     line-height: 1.5;       /* betere leesbaarheid */
#   }
#
#   .opmerking strong {
#     color: #1b5e20;         /* extra nadruk */
#   }
# </style>
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li>Dit is de systematische aanpak die voor alle problemen werkt. Vaak niet de efficientste: inzichten bieden snellere oplossingen vaak
#     <li> We gaan dus deze methode implementeren, maar moeten nog altijd de ad hoc inzichten hebben en dergelijke
#     <li> Snelheidsvergelijkingen kunnen pas nadat de positie gelsoten is, zijnde berekend is. De krachtvergelijkingen kunnen op hun beurt pas bepaald worden als de snelheden gesloten zijn.
#   </ul>
# </div>
#
# <div style="height: 15rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/planar-four-bar-linkage.png"
#  >
# </div>
#
# <p><span style="color: Maroon;"><b>Sluitingsvergelijkingen</b></span>: we weten dat de vier stangen in het mechanisme altijd met elkaar verbonden zijn. Er moet altijd een sluiting zijn, er zijn meerdere formuleringen maar kern is altijd hetzelfde. Dus geldt de volgende gelijkheid:
#
# $$\bf r_2 + r_3 = r_1 + r_4.$$
#
# Projectie op de coordinaat-assen van het vaste gelid ($X$ horizontaal langs $r_1$, en $Y$ vertikaal) geeft de volgende twee scalaire vergelijkingen:
#
# \begin{aligned}
# X &: r_2 \cos(\theta_2) + r_3 \cos(\theta_3) -r_4 \cos(\theta_4) - r_1 = 0,
# \\
# Y &: r_2 \sin(\theta_2) + r_3 \sin(\theta_3) -r_4 \sin(\theta_4) = 0.
# \end{aligned}
#
#
# <div class="opmerking">
#   <strong>Gekenden:</strong>
#   <ul>
#     <li>De hoek theta_2: we nemen aan dat er een encoder op onze motor staat. Algemeen kan je altijd alle "aandrijf-eigenschappen" als gekend beschouwen.
#     <li> De geometrische parameters zijn ook als gekend te beschouwen
#   </ul>
# </div>
#
# Dit geeft een stelsel van twee <b>niet-lineaire</b> vergelijkingen in de twee onbekenden $\theta_3$ en $\theta_4$.
# Hiervoor bestaan <b>numerieke &ldquo;solvers&rdquo;</b> (bijv. gebaseerd op een <a href="https://en.wikipedia.org/wiki/Newton%27s_method">Newton-Raphson methode</a>), die starten met geschatte initi&euml;le waarden $\theta_3^0$ en $\theta_4^0$.
#
# In veel software-programma's heet zo'n algemene &ldquo;solver&rdquo;
# <tt>fsolve</tt>; dat is ook zo in de <a href="https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.fsolve.html">Python code</a> die we in dit vak gebruiken.
#
# Conclusie: deze <em>numerieke</em> methode van de <em>sluitingsvergelijkingen</em> voor elke (onafhankelijke!) <em>kringloop</em> (&ldquo;loop&rdquo;) in het mechanisme is <b>heel generiek</b>. <span style="color: Maroon;"><b>We zullen die aanpak nog erg veel gebruiken in het vak</b></span>.
#
# </div>

# %%
# Animation of four bar


import matplotlib

import ipympl
import matplotlib.pyplot as plt

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve
import matplotlib.animation as animation

# %matplotlib widget

# %%
# Example analysis of a four-bar mechanism.

# Data initialization (all data is in SI units)
# kinematic parameters (link lengths)
r1 = 0.1397 #m
r2 = 0.0508 #m
r3 = 0.1524 #m
r4 = 0.0762 #m
phi1 = 0 #rad

# %%
# STEP 1. Determination of Kinematics

# position analysis
phi3_init = 0  # initial condition for first step of position analysis with fsolve (phi3 and phi4)
phi4_init = 0.2  # VERY IMPORTANT because it determines which branch of the mechanism you're in

t_begin =  0     # start time of simulation
t_end   = 15     # end time of simulation
Ts      =  0.05  # time step of simulation
t = np.arange(t_begin, t_end + Ts, Ts)  # time vector

# initialization of driver
omega = 0.5      # driver frequency
A     = 1        # amplitude
# angular position, velocity and acceleration:
phi2   = 1 + A * np.sin(omega * t)
dphi2  = omega * A * np.cos(omega * t)
ddphi2 = -omega ** 2 * A * np.sin(omega * t)

# %%
# Function to rotate a vector z over an angle theta:
def rotate_vector(z, theta):
    rotation_matrix = np.array([[np.cos(theta), -np.sin(theta)],
                                [np.sin(theta), np.cos(theta)]])
    return np.dot(rotation_matrix, z)

# %%
# Define loop closure equations
def loop_closure_eqs(phi_init, phi2, r1, r2, r3, r4, phi1):
    phi3 = phi_init[0]
    phi4 = phi_init[1]

    # Loop closure equations
    F1 = r2 * np.cos(phi2) + r3 * np.cos(phi3) - r4 * np.cos(phi4) - r1 * np.cos(phi1)
    F2 = r2 * np.sin(phi2) + r3 * np.sin(phi3) - r4 * np.sin(phi4) - r1 * np.sin(phi1)

    return [F1, F2]

# %%
# Define kinematic computations of the four-bar mechanism

def kinematics_4bar(r1, r2, r3, r4, phi1, phi2, dphi2, ddphi2, phi3_init, phi4_init, t):
    global phi3, phi4, dphi3, dphi4, ddphi3, ddphi4
    phi3   = np.zeros_like(t)
    phi4   = np.zeros_like(t)
    dphi3  = np.zeros_like(t)
    dphi4  = np.zeros_like(t)
    ddphi3 = np.zeros_like(t)
    ddphi4 = np.zeros_like(t)

    optim_options = {"full_output":True}  # options for fsolve

    for k, time in enumerate(t):
        # Position Analysis
        x, _, ier, message  = fsolve(lambda x: loop_closure_eqs(x, phi2[k], r1, r2, r3, r4, phi1), [phi3_init, phi4_init], **optim_options)

        if ier != 1:
            print("The fsolve exit flag was not 1, probably no convergence!")
            print(message)

        phi3[k] = x[0]
        phi4[k] = x[1]

        # Velocity Analysis
        A = np.array([[-r3 * np.sin(phi3[k]), r4 * np.sin(phi4[k])],
                      [r3 * np.cos(phi3[k]), -r4 * np.cos(phi4[k])]])
        B = np.array([r2 * np.sin(phi2[k]) * dphi2[k],
                      -r2 * np.cos(phi2[k]) * dphi2[k]])

        x = np.linalg.solve(A, B)
        dphi3[k] = x[0]
        dphi4[k] = x[1]

        # Acceleration Analysis
        B = np.array([r2 * np.cos(phi2[k]) * dphi2[k]**2 + r2 * np.sin(phi2[k]) * ddphi2[        k] + r3 * np.cos(phi3[k]) * dphi3[k]**2 - r4 * np.cos(phi4[k]) * dphi4[k]**2,
                      r2 * np.sin(phi2[k]) * dphi2[k]**2 - r2 * np.cos(phi2[k]) * ddphi2[k] + r3 * np.sin(phi3[k]) * dphi3[k]**2 - r4 * np.sin(phi4[k]) * dphi4[k]**2])

        x = np.linalg.solve(A, B)
        ddphi3[k] = x[0]
        ddphi4[k] = x[1]

        # Next iteration step
        phi3_init = phi3[k] + (t[1] - t[0]) * dphi3[k]
        phi4_init = phi4[k] + (t[1] - t[0]) * dphi4[k]


    global movie_axes, fig, P, S
    # next step in the animation:
    def update(frame):
        plt.cla()  # Clear the current axes
        plt.axis('equal')  # Ensures 1 unit on x == 1 unit on y
    
        # Calculate Cartesian coordinates using rotation matrix
        Q = P + rotate_vector(np.array([r2, 0]), phi2[frame])
        R1 = Q + rotate_vector(np.array([r3, 0]), phi3[frame])
        R2 = S + rotate_vector(np.array([r4, 0]), phi4[frame])
    
        loop1 = np.array([P, Q, R1, R2, S])
    
        plt.plot(loop1[:, 0], loop1[:, 1], '-o')
        plt.axis(movie_axes)
        plt.title(f'Frame {frame}')

    # Update the animation
    global ani, index_vec, index_vec, fig
    ani = animation.FuncAnimation(fig, update, frames=len(index_vec), interval=50)
    plt.show()

# %%
# Animation of mechanism motion
# compute width and height of drawing canvas:
x_left   = -1.25 * r2
y_bottom = -1.25 * max(r2, r4)
x_right  = r1 + 1.25 * r4
y_top    = 1.25 * max(r2, r4)

# Initialize the figure
global fig
fig = plt.figure(1)
ax = fig.add_subplot(111)
ax.set_xlim((x_left, x_right))
ax.set_ylim((y_bottom, y_top))
plt.xlabel('[m]')
plt.ylabel('[m]')

# Define the function to update the plot for each frame:
global movie_axes
movie_axes = [x_left, x_right, y_bottom, y_top]
t_size = len(t)

global P, S
# Define point P
# P = 0
P = np.array([0,0])

# Define point S
S = rotate_vector(np.array([r1, 0]), phi1)

# Define the number of fra        mes in the movie
frames = t_size/2
# Calculate the time between frames
delta = int(np.floor(t_size / frames))
# Define the index vector for frames        
global index_vec
index_vec = np.arange(0, t_size, delta)

# calculation and visualisation of the kinematics:
kinematics_4bar(r1, r2, r3, r4, phi1, phi2, dphi2, ddphi2, phi3_init, phi4_init, t)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <div style="width: 76ch;">
#
# <h3>Snelheids-analyse gebaseerd op geometrisch inzicht</h3>
#
# <div style="height: 15rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/planar-four-bar-linkage.png"
#  >
# </div>
#
# Het inzicht start door de geometrische verbanden expliciet te maken tussen
# de tijdsafgeleiden (&ldquo;hoeksnelheden&rdquo;)
# $\omega_2$, $\omega_3$, en $\omega_4$ van de hoeken $\theta_2$, $\theta_3$, en $\theta_4$, en de lineaire snelheden $v_A$ en $v_B$:
#
# <div style="display: grid; grid-template-columns: 1fr 2fr; grid-column-gap: 1%;">
# <div>
#
# \begin{aligned}
# v_A &= \omega_2 \times r_2,
# \\
# v_B &= \omega_4 \times r_4,
# \\
# v_B &= v_A + \omega_3 \times r_3.
# \end{aligned}
#
# </div>
# <div>
# <br>
# (gekend want gemeten aan de aandrijvende motor!)
# </div>
# </div>
#
#
#
# Dit geeft een stelsel van twee <b>lineaire</b> vergelijkingen in de twee onbekenden $\omega_3$ en $\omega_4$.
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
# <h3>Snelheids-analyse gebaseerd op sluitingsvergelijkingen</h3>
#
# <div style="height: 15rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/planar-four-bar-linkage.png"
#  >
# </div>
#
# De tijdsafgeleide van de <em>positie</em>-sluitingsvergelijkingen
#
# \begin{aligned}
# &X: r_2 \cos(\theta_2) + r_3 \cos(\theta_3) -r_4 \cos(\theta_4) - r_1 = 0,
# \\
# &Y: r_2 \sin(\theta_2) + r_3 \sin(\theta_3) -r_4 \sin(\theta_4) = 0.
# \end{aligned}
#
# geeft
#
# \begin{aligned}
# &X: −r_2 \sin(\theta_2) \omega_2 − r_3 \sin(\theta_3) \omega_3 + r_4 \sin(\theta_4)  \omega_4 = 0,
# \\
# &Y: r_2 \cos(\theta_2) \omega_2 + r_3 \cos(\theta_3) \omega_3 − r_4 cos(\theta_4 ) \omega_4 = 0.
# \end{aligned}
#
# Met andere woorden, een <b>lineair</b> stelsel van <b>twee onbekenden</b> $\omega_3$ en $\omega_4$.
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
# <h3>Versnellings-analyse met geometrisch inzicht</h3>
#
# Heel erg gelijkaardig aan de snelheidsanalyse:
# gegeven $\theta_2$, $\theta_3,\theta_4$, $\omega_2$, $\omega_3$, $\omega_4$, en $\alpha_2$ (de &ldquo;gemeten&rdquo;) hoekversnelling van gewricht 2), vind de hoekversnellingen $\alpha_3$ en $\alpha_4$. We starten met het inzicht dat we de lineaire versnellingen van de gewrichten A en B als volgt kunnen linken met de hoeksnelheden en -versnellingen:
#
# \begin{aligned}
# a_A &= \alpha_2 \times r_2 + \omega_2 \times \omega_2 \times r_2, \quad \text{(gekend!)}
# \\
# a_B &= \alpha_4 \times r_4 + \omega_4 \times \omega_4 \times r_4,
# \\
# a_B &= a_A + \alpha_3 \times r_3 + \omega_3 \times \omega_3 \times r_3.
# \end{aligned}
#
# Het resultaat is opnieuw een stelsel van <b>lineaire</b> vergelijkingen in de onbekenden $\alpha_3$ en $\alpha_4$.
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
# <h3>Versnellings-analyse gebaseerd op sluitingsvergelijkingen</h3>
#
# De tijdsafgeleide van de snelheids-sluitingsvergelijkingen
#
# \begin{aligned}
#  0 =&−r_2 \sin(\theta_2) \omega_2 − r_3 \sin(\theta_3) \omega_3 + r_4 \sin(\theta_4)  \omega_4,
# \\
#  0 =&r_2 \cos(\theta_2) \omega_2 + r_3 \cos(\theta_3) \omega_3 − r_4 cos(\theta_4 ) \omega_4.
# \end{aligned}
#
# geeft
#
# \begin{aligned}
# 0 = &−r_2 cos(θ_2)ω_2^2 − r_3 cos(θ_3)ω_3^2 + r_4 cos(θ_4)ω_4^2,
# \\
#  &− r_2 sin(θ_2)α_2 − r_3 sin(θ_3)α_3 + r_4 sin(θ_4)α_4,
# \\
# 0 = &−r_2 sin(θ_2)ω_2^2 − r_3 sin(θ_3)ω_3^2 + r_4 sin(θ_4)ω_4^2
# \\
#  &+ r_2 cos(θ_2)α_2 + r_3 cos(θ_3)α_3 − r_4 cos(θ_4)α_4.
# \end{aligned}
#
# Het resultaat is opnieuw een stelsel van <b>lineaire</b> vergelijkingen in de onbekenden $\alpha_3$ en $\alpha_4$.
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
# <h2>Kruk-drijfstang-mechanisme (&ldquo;slider-crank&rdquo;)</h2>
#
# <div style="display: grid; grid-template-columns: 3fr 1fr; grid-column-gap: 1%;">
#
# <div style=" display: grid; place-items: center; place-content: center;">
#  <div style="height: 12rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/kruk-drijfstang.png"
#  >
#  </div>
# </div>
#
# <div style=" display: grid; place-items: center; place-content: center;">
#  <div style="height: 15rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/4StrokeEngine_Ortho_3D_Small.gif"
#  >
#  </div>
# </div>
#
# </div>
#
# <div>
# <b>Terminologie</b>:
# <div style="display: grid; grid-template-columns: 1fr 1fr; grid-column-gap: 1%;">
# <div>
# <ul>
# <li>2: kruk (&ldquo;crank&rdquo;) met lengte R.
# <li>3: drijfstang (&ldquo;connecting rod &rdquo;) met lengte L.
# <li>4: zuiger (&ldquo;slider&rdquo;).
# <li>krukpen, zuigerpen.
# </ul>
# </div>
# <div>
# <ul>
# <li>θ: krukhoek.
# <li>φ: orientatie van drijfstang.
# <li>x: positie van de zuiger, gemeten vanaf het bovenste <b>dode punt</b>, dat is, waar kruk en drijfstang in het verlengde komen te liggen van de zuiger.
# </ul>
# </div>
# </div>
# </div>
#
# Vaak gemaakte ontwerpkeuzes:
# - L ≃ 4R.
# - de as van het prismatisch gewricht van de zuiger gaat door het rotatiecentrum van de kruk.
#
# Door een dood punt bewegen met behulp van een vliegwiel is makkelijker wanneer de kruk het aandrijvend gelid is dan wanneer de zuiger dat is.
#
# <b>Toepassingen</b>:
# <ul>
# <li>zuiger<em>motoren</em>: zuiger is de aangedreven link.
# <li>zuiger<em>compressoren</em>: kruk is de aangedreven link.
# <li>werktuigen zoals <a href="https://en.wikipedia.org/wiki/Deep_drawing">dieptrekken</a>, <a href="https://en.wikipedia.org/wiki/Planer_(metalworking)">schaafbank</a>, enz.
# </ul>
# De nadelen als werktuig zijn:
# <ul>
# <li>de heen-beweging duurt even lang als de terugkeer-beweging.
# <li>de snelheid verandert gedurende het &ldquo;snij&rdquo;-proces.
# </ul>
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
# <h3>Positie-analyse gebaseerd op sluitingsvergelijkingen</h3>
#
# <style>
#   .opmerking {
#     border-left: 5px solid #2e7d32;
#     background-color: #e8f5e9;
#     color: #1b1b1b;          /* donkere tekst */
#     padding: 14px 18px;
#     margin: 16px 0;
#     font-family: Arial, sans-serif;
#     font-size: 16px;        /* duidelijker */
#     line-height: 1.5;       /* betere leesbaarheid */
#   }
#
#   .opmerking strong {
#     color: #1b5e20;         /* extra nadruk */
#   }
# </style>
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li>Soms is assymetrie tussen heengaande en terugkomende beweging een voordeel. Je kan dit bekomen door excentriciteit
#   </ul>
# </div>
#
# <div style="height: 14rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/kruk-drijfstang.png"
#  >
# </div>
#
# <b>Gegeven</b> $\theta$, <b>vind</b> $\phi$ en $x$.
#
# <p id="crank-position-closure"><b>Sluitingsvergelijking</b>:
#
# \begin{aligned}
# X:  0 &= R \cos(\theta) + L \cos(\phi) - (L+R-x),
# \\
# Y:  0 &= R \sin(\theta) - L \sin(\phi).
# \end{aligned}
#
# Dit levert een stelsel <b>niet-lineaire</b> vergelijkingen op, in de twee onbekenden $\phi$ en $x$.
# Dit stelsel kan <b>numeriek</b> opgelost worden, met beginschattingen van de onbekenden als input.

# %% [markdown]
# <div style="width: 76ch;">
#
# <h3>Benaderende positie-analyse</h3>
#
# Aangezien vaak $L \approx 4R$, kan <a href="#SE">deze positie-vergelijking</a> benaderd worden als
#
# $$x \approx
# R(1 − \cos \omega t) +
# \frac{R^2}{4L}
# (1 − \cos 2\omega t).
# $$
#
# Met gelijkaardige resultaten voor snelheid en versnelling:
#
# \begin{aligned}
# v &\approx R \omega \sin(\omega t) + \frac{R^2}{2L} \sin(2 \omega t),
# \\
# a &\approx R \omega^2 \cos(\omega t) + \frac{R^2}{L} \cos(2 \omega t),
# \end{aligned}
#
# Deze vergelijkingen leveren een goede basis voor de studie van <b>trillingen</b> in machines. Merk ook op dat de tweede harmonische <b>belangrijker</b> wordt in hogere afgeleiden.
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
# <h3>Kruk-drijfstang met excentrische drijfstang</h3>
#
# De bouw van het <a href="https://en.wikipedia.org/wiki/Eccentric_(mechanism)">mechanisme</a> is dusdanig dat de as van de lineaire zuigerbeweging <em>niet</em> door het rotatie-centrum van de kruk gaat.
# Die <em>excentriciteit</em> zorgt voor een asymmetrische snelheid in heengaande en terugkerende bewegingsfases.
# (Het fenomeen is het goed te zien op deze
# <a href="https://www.youtube.com/watch?v=XZYNb46lwHo">video</a>.)
#
# <div style="height: 12rem; text-align: center;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/slider-crank-eccentric-slider.png"
#  >
# </div>
#
# <div style="height: 26rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/Crank_Sliders-quick-return.gif"
#  >
# </div>
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
# <h3>Snelle terugkeer-mechanisme</h3>
#
# Straal van de heengaande beweging (&ldquo;stroke&rdquo;) is groter dan de straal van de terugkerende beweging (&ldquo;return stroke&rdquo;).
# (<a href="https://www.youtube.com/watch?v=rKIoP67_MAI">video1</a>,
# <a href="https://www.youtube.com/watch?v=UuTNtg7-Bwg">video2</a>)
#
# <style>
#   .opmerking {
#     border-left: 5px solid #2e7d32;
#     background-color: #e8f5e9;
#     color: #1b1b1b;          /* donkere tekst */
#     padding: 14px 18px;
#     margin: 16px 0;
#     font-family: Arial, sans-serif;
#     font-size: 16px;        /* duidelijker */
#     line-height: 1.5;       /* betere leesbaarheid */
#   }
#
#   .opmerking strong {
#     color: #1b5e20;         /* extra nadruk */
#   }
# </style>
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li>Geef aan als je een toepassing weet waarbij de omkeer van aandrijving en nuttige beweging nuttig is. Dit is een sterk voordeel, het moet wel nuttig zijn ens
#   </ul>
# </div>
#
# <div style="padding-top: 1rem; display: grid; grid-template-columns: 1fr 1fr; grid-column-gap: 1%;">
#
# <div style=" display: grid; place-items: center; place-content: center;">
# <a href="https://en.wikipedia.org/wiki/File:Quick_Return_Mechanism_1.gif">
#  <div style="height: 20rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/Quick_Return_Mechanism_1.gif"
#  >
#  </div>
# </a>
# </div>
#
# <div style=" display: grid; place-items: center; place-content: center;">
# <a href="https://en.wikipedia.org/wiki/File:Shaper.png">
#  <div style="height: 20rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/Quick-return-mechanism-nomenclature.png"
#  >
#  </div>
# </a>
# </div>
#
# </div>
#
# Voor een <b>constante</b> kruksnelheid geeft het mechanisme een <b>snelle</b> beweging in de ene richting, en een <b>trage</b> in de andere.
# Die trage beweging gebeurt met een zo gelijkmatig mogelijke snelheid, want dat is vaak de &ldquo;bewerkende&rdquo; beweging.
# Bijvoorbeeld voor een <a href="https://en.wikipedia.org/wiki/Shaper">schaafbank</a>.
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; grid-column-gap: 1%;">
#
# <div style="height: 26rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/swing-arm.png"
#  >
# </div>
#
# <div>
#
# <b>Tijdsverhouding</b> heen-en-terug bewegingen: $\frac{\alpha}{\beta} > 1$.
#
# Mobiliteit: $M = 3 \times (6 − 1) − 2 \times 7 = 1$.
#
# <b>&Eacute;&eacute;n</b> aandrijflink: kruk 2.
#
# <b>Twee</b> onafhankelijke <em>kinematische lussen</em>:
# <ul>
# <li>1−2−3−4−1
# <li>1−2−3−4−5−6−1
# </ul>
#
# <b>Vier</b> scalaire <b>positie-sluitings</b> vergelijkingen.
#
# <b>Vier</b> onbekenden:
# <ul>
# <li>
#
# positie link 3 t.o.v. link 4: $x_3$.
# <li>
#
# orientatie van link 4: $\theta_4$.
# <li>
#
# orientatie van link 5: $\theta_5$
# <li>
#
# positie link 6 t.o.v. link 1: $x_6$
# </ul>
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
# <h3>Dubbele-kruk-aandrijving (&ldquo;drag link&rdquo;)</h3>
#
# <style>
#   .opmerking {
#     border-left: 5px solid #2e7d32;
#     background-color: #e8f5e9;
#     color: #1b1b1b;          /* donkere tekst */
#     padding: 14px 18px;
#     margin: 16px 0;
#     font-family: Arial, sans-serif;
#     font-size: 16px;        /* duidelijker */
#     line-height: 1.5;       /* betere leesbaarheid */
#   }
#
#   .opmerking strong {
#     color: #1b5e20;         /* extra nadruk */
#   }
# </style>
#
# <div class="opmerking">
#   <strong>Opmerking:</strong>
#   <ul>
#     <li>Bekijk de videos
#   </ul>
# </div>
#
# <div style="display: grid; grid-template-columns: 1fr 2fr; grid-column-gap: 1%;">
#
# <div style="display: grid; place-items: center; place-content: center;">
#  <div style="height: 26rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/drag-link.png"
#  >
#  </div>
# </div>
#
# <div>
#  (<a href="https://www.youtube.com/watch?v=Ac2eceeBiQg">video</a>,
#  <a href="https://www.youtube.com/watch?v=byH6i8U76C8">video</a>)
# <ul>
# <li>combinatie van een vierstangen-mechanisme met een kruk-drijfstang-mechanisme:
# <ul>
# <li>kruk 2 roteert met constante snelheid.
# <li>kruk 4 roteeert met niet-constante snelheid, en drijft de drijfstang 5 aan.
# </ul>
# <li>resulterende beweging van zuiger 6:
# <ul>
# <li>opgaande slag: <em>traag</em> met bijna constante snelheid.
# <li>neergaande slag: <em>snelle</em> beweging.
# </ul>
# <li>bereken de tijdsverhouding tussen de extreme posities: vul in&hellip;
# <li>onafhankelijke kinematische lussen: vul in&hellip;
# <li>onbekenden: vul in&hellip;
# </ul>
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
# <h3>Dubbele-kruk-sleuf-mechanisme (&ldquo;Whitworth mechanisme&rdquo;)</h3>
#
# <div style="height: 14rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/Whitworth-mechanism.png"
#  >
# </div>
# (<a href="https://www.youtube.com/shorts/9ghjDxqweW8">video</a>,
# <a href="https://www.youtube.com/watch?v=Ac2eceeBiQg">video</a>)
#
# Combinatie van:
# <ol>
# <li>vierstangen-mechanisme (1-2-3-4) met drijfstang van lengte 0 (in gewricht 3), en met &eacute;&eacute;n rotatie-gewricht (3) vervangen door een zuiger.
# <li>met een kruk-drijfstang mechanisme 4-5-6:
# <ul>
# <li>kruk 2 roteert met constante snelheid
# <li>kruk 4 roteert met niet-constante snelheid, en drijft zuiger 6 aan.
# </ul>
# </ol>
#
# Resulterende beweging van zuiger 6:
# <ul>
# <li>heengaande beweging: <em>traag</em>, ongeveer constante snelheid.
# <li>terugkerende beweging: varierende snelheid.
# </ul>
#
# Bereken de tijdsverhouding tussen de extreme posities:
# extreme posities doen zich voor wanneer links 4 en 5 gealigneerd zijn: &hellip;
#
# Onafhankelijke kinematische lussen: &hellip;
#
# Onbekenden: &hellip;
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
# <h3>Onderbroken beweging met Maltezerkruis (&ldquo;<a href="https://en.wikipedia.org/wiki/Geneva_drive">Geneva Wheel</a>&rdquo;)</h3>
#
# <div style="height: 8rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/Geneva-drive-stop-positions.png"
#  >
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/Geneva_mechanism_6spoke_animation.gif"
#  >
# </div>
#
# <b>Onderbroken beweging</b>:
# <ul>
# <li>in bepaalde delen van de aandrijvende beweging beweegt het aangedreven deel ook.
# <li>in de andere delen staat dat laatste stil (&ldquo;stilstand&rdquo;, &ldquo;dwell&rdquo;).
# </ul>
#
# <div style="display: grid; grid-template-columns: 1fr 2fr; grid-column-gap: 1%;">
#
# <div style="height: 20rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/Geneva-wheel-annotated.png"
#  >
# </div>
#
# <div>
# <b>Eigenschappen</b>:
# de krukpen P gaat <em>tangentieel</em> binnen in een radiaal uitgesneden <em>sleuf</em>.
# Dit minimizeert de &ldquo;ingrijpschok&rdquo; bij het in elkaar grijpen van de tandwielen
#
# De <b>vergrendelingsplaat</b> blokeert het Maltezerkruis gedurende de stilstand.
#
# <b>Toepassingen</b>:
# <ul>
# <li>werktuigmachines: <a href="https://www.youtube.com/watch?v=MGVrv6bNO_4">draaibare gereedschapshouder</a> in een revolverdraaibank.
# <li>blokkeermechanisme om uurwerken te beschermen tegen te ver opwinden.
# </ul>
# </div>
#
# </div>
#
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
# <h3>Andere mechanismes voor onderbroken beweging: palrad (&ldquo;<a href="https://en.wikipedia.org/wiki/Ratchet_(device)">ratchet</a>&rdquo;)</h3>
#
# <div style="height: 15rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/ratchet-mechanism.png"
#  >
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/Ratchet_Gear_and_Pawl.gif"
#  >
# </div>
#
# <div>
# Converteert continue <em>rotatie</em>-beweging in een bepaalde richting, in een onderbroken
# <em>heen-en-weergaande</em> beweging, en blokkeert de rotatie in de andere richting.
#
# <b>Toepassing</b>: mechanische &ldquo;tel&rdquo;-machine.
# </div>
#
# </div>

# %% [markdown]
# <div style="width: 76ch;">
#
# <h3>Andere mechanismes voor onderbroken beweging: onderbroken transmissie</h3>
#
#
# <div style="height: 10rem;">
#  <img style="border: 0; display: inline-block;" height="100%"
#       src="images/intermittent-gear-transmission.png"
#  >
# (<a href="https://www.youtube.com/watch?v=y7PRkA-INos">video</a>)
# </div>
#
# </div>
